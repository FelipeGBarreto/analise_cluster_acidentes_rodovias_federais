# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv("/Users/felipebarreto/Desktop/dados_acidentes_tratados.csv", sep = ',', encoding='latin1')

# %%
dataset.head()
# Out:
#           id        data  turno dia_semana  uf        municipio  \
# 0       10.0  2007-06-11  Tarde    Segunda  MG         OLIVEIRA
# 1  1032898.0  2007-08-13  Tarde    Segunda  MG        ITABIRITO
# 2  1051130.0  2007-02-12  Noite    Segunda  MA         SAO LUIS
# 3  1066824.0  2007-11-20  Noite      Terça  CE          CAUCAIA
# 4  1069918.0  2007-12-16  Tarde    Domingo  MA  BARAO DE GRAJAU
#
#                 causa_acidente            tipo_acidente  \
# 0             Falta de atenção          Colisão frontal
# 1                       Outras           Saída de Pista
# 2             Animais na Pista  Atropelamento de animal
# 3  Defeito mecânico em veículo              Capotamento
# 4                       Outras              Capotamento
#
#   classificacao_acidente     fase_dia  ... tracado_via uso_solo pessoas  \
# 0                 (null)    Pleno dia  ...        Reta    Rural       9
# 1    Com Vítimas Feridas    Pleno dia  ...        Reta    Rural       3
# ...

# %%
df = dataset.copy().drop(['id','pessoas','feridos'], axis=1)

df.head()
# Out:
#          data  turno dia_semana  uf        municipio  \
# 0  2007-06-11  Tarde    Segunda  MG         OLIVEIRA
# 1  2007-08-13  Tarde    Segunda  MG        ITABIRITO
# 2  2007-02-12  Noite    Segunda  MA         SAO LUIS
# 3  2007-11-20  Noite      Terça  CE          CAUCAIA
# 4  2007-12-16  Tarde    Domingo  MA  BARAO DE GRAJAU
#
#                 causa_acidente            tipo_acidente  \
# 0             Falta de atenção          Colisão frontal
# 1                       Outras           Saída de Pista
# 2             Animais na Pista  Atropelamento de animal
# 3  Defeito mecânico em veículo              Capotamento
# 4                       Outras              Capotamento
#
#   classificacao_acidente     fase_dia  sentido_via condicao_metereologica  \
# 0                 (null)    Pleno dia  Decrescente              Ceu Claro
# 1    Com Vítimas Feridas    Pleno dia    Crescente              Ceu Claro
# 2     Com Vítimas Fatais  Plena noite    Crescente              Ceu Claro
# ...

# %%
df.data.value_counts()
# Out:
# 2011-03-05    1100
# 2011-04-21    1030
# 2011-03-04    1001
# 2010-12-23     992
# 2012-12-22     957
#               ...
# 2021-03-15       2
# 2021-08-11       2
# 2021-07-02       2
# 2021-12-21       1
# 2021-08-24       1
# Name: data, Length: 5478, dtype: int64

# %%
df.uso_solo = df.uso_solo.map({
    '(null)':None,
    'Rural': 'Rural',
    'Urbano': 'Urbano',
    'Não': 'Não',
    'Sim': 'Sim'
})

# %%
df.columns
# Out:
# Index(['data', 'turno', 'dia_semana', 'uf', 'municipio', 'causa_acidente',
#        'tipo_acidente', 'classificacao_acidente', 'fase_dia', 'sentido_via',
#        'condicao_metereologica', 'tipo_pista', 'tracado_via', 'uso_solo',
#        'mortos', 'feridos_leves', 'feridos_graves', 'ilesos', 'ignorados',
#        'veiculos'],
#       dtype='object')

# %%
lista_categorias = [ 'turno', 'dia_semana', 'uf', 'municipio', 'causa_acidente',
       'tipo_acidente', 'classificacao_acidente', 'fase_dia', 'sentido_via',
       'condicao_metereologica', 'tipo_pista', 'tracado_via', 'uso_solo']

# %%
for i in lista_categorias:
    print(f"{i}: {df[i].unique()}\n")
# Out:
# turno: ['Tarde' 'Noite' 'ManhÃ£']
#
# dia_semana: ['Segunda' 'Terça' 'Domingo' 'Quinta' 'Quarta' 'Sexta' 'Sábado' 'domingo'
#  'segunda-feira' 'terça-feira' 'sexta-feira' 'quarta-feira' 'quinta-feira'
#  'sábado']
#
# uf: ['MG' 'MA' 'CE' 'PR' 'ES' 'GO' 'RJ' 'RS' 'SP' 'RN' 'SC' 'PA' 'PE' 'MT'
#  'BA' 'AL' 'TO' 'PI' 'MS' 'SE' 'RO' 'PB' 'AP' 'DF' 'AC' 'RR' 'AM' '(null)']
#
# municipio: ['OLIVEIRA' 'ITABIRITO' 'SAO LUIS' ... 'GLORIA DE DOURADOS'
#  'SAO JOAO DO SOTER' 'PASSOS MAIA']
#
# causa_acidente: ['Falta de atenção' 'Outras' 'Animais na Pista'
#  'Defeito mecânico em veículo' 'Não guardar distância de segurança'
#  'Velocidade incompatível' 'Desobediência à sinalização'
#  'Ingestão de álcool' 'Defeito na via' 'Dormindo' 'Ultrapassagem indevida'
#  '(null)' 'Desobediência às normas de trânsito pelo condutor'
#  'Velocidade Incompatível' 'Ingestão de Álcool'
#  'Restrição de Visibilidade' 'Falta de Atenção à Condução'
#  'Defeito Mecânico no Veículo' 'Falta de Atenção do Pedestre'
# ...

# %%
pd.DataFrame(
    df['causa_acidente']
    .value_counts()
    .head(20)
).reset_index()\
 .rename(
    columns = {
        'index': 'Causa do Acidente'
    }
)
# Out:
#                                     Causa do Acidente  causa_acidente
# 0                                    Falta de atenção          507430
# 1                                              Outras          451211
# 2                  Não guardar distância de segurança          150883
# 3                             Velocidade incompatível          133913
# 4                         Falta de Atenção à Condução           65037
# 5                         Desobediência à sinalização           63684
# 6                         Defeito mecânico em veículo           62921
# 7                                  Ingestão de álcool           61433
# 8                                    Animais na Pista           46418
# 9                                            Dormindo           40909
# 10                             Ultrapassagem indevida           35263
# 11                                     Defeito na via           23595
# ...

# %%
pd.pivot(
    df[['data','turno','dia_semana']],
    columns=['turno'], 
    values='data'
).fillna(0)
# Out:
# turno        ManhÃ£       Noite       Tarde
# 0                 0           0  2007-06-11
# 1                 0           0  2007-08-13
# 2                 0  2007-02-12           0
# 3                 0  2007-11-20           0
# 4                 0           0  2007-12-16
# ...             ...         ...         ...
# 1737864           0  2021-11-14           0
# 1737865           0  2021-10-01           0
# 1737866           0  2021-12-14           0
# 1737867  2021-11-30           0           0
# 1737868           0  2021-07-19           0
#
# [1737869 rows x 3 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/envs/PicPay/lib/python3.8/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2186         try:
# -> 2187             values, tz_parsed = conversion.datetime_to_datetime64(data.ravel("K"))
#    2188             # If tzaware, these values represent unix timestamps, so we
#
# ~/opt/anaconda3/envs/PicPay/lib/python3.8/site-packages/pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# OutOfBoundsDatetime                       Traceback (most recent call last)
# ...
